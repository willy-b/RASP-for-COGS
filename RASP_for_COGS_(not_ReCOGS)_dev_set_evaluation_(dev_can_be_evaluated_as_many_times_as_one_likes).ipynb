# %% [markdown]
# RASP-for-COGS (NOT ReCOGS) dev set evaluation PR#1 (dev set can be evaluated as many times as one likes, not test/gen)

# %%
# !apt update
# !apt upgrade python3
# !apt upgrade python3-pip
# !apt install python3.10-venv
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [69.9 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,378 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,754 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,955 kB]
# ...

# %%
# %cd /content
# !rm -rf RASP*
# Out:
# /content

# %%
# !git clone _/RASP-for-COGS.git
# Out:
# Cloning into 'RASP-for-COGS'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 32 (delta 15), reused 26 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 84.16 KiB | 4.01 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# %cd RASP-for-COGS
# Out:
# /content/RASP-for-COGS

# %%
# !git checkout pre-eval-cleanup-remove-redundant-RASP-and-make-v_inf_taking_to_v_inf-xcomp-right_idx-2nd-verb-selector-verb-specific-for-safety #-2-without-comments
# Out:
# Branch 'pre-eval-cleanup-remove-redundant-RASP-and-make-v_inf_taking_to_v_inf-xcomp-right_idx-2nd-verb-selector-verb-specific-for-safety' set up to track remote branch 'pre-eval-cleanup-remove-redundant-RASP-and-make-v_inf_taking_to_v_inf-xcomp-right_idx-2nd-verb-selector-verb-specific-for-safety' from 'origin'.
# Switched to a new branch 'pre-eval-cleanup-remove-redundant-RASP-and-make-v_inf_taking_to_v_inf-xcomp-right_idx-2nd-verb-selector-verb-specific-for-safety'

# %%
# !git log -v -n 1 | grep commit
# Out:
# commit 8aeef4c8c8b12d59c36bcb9df1bd1185e848beda

# %%
# !python cogs_examples_in_rasp.py --use_dev_split
# Out:
# Note the RASP dependency requires python3.10-venv and its own dependencies; if there are errors please check the RASP dependencies' instructions (and run `apt install python3.10-venv` or equivalent for your operating system)
# Cloning into 'RASP'...
# remote: Enumerating objects: 428, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 428 (delta 151), reused 145 (delta 121), pack-reused 216 (from 1)
# Receiving objects: 100% (428/428), 319.15 KiB | 8.86 MiB/s, done.
# Resolving deltas: 100% (222/222), done.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# The following packages were automatically installed and are no longer required:
#   linux-headers-5.15.0-127 linux-headers-5.15.0-127-generic
# Use 'sudo apt autoremove' to remove them.
# The following NEW packages will be installed:
#   rlwrap
# ...

# %% [markdown]
# (restart previous command without changes to any files as something external interrupted loading of RASP program via python bridge, had not even downloaded dataset yet)

# %%
# !python cogs_examples_in_rasp.py --use_dev_split
# Out:
# Streaming output truncated to the last 5000 lines.
#  girl ( x _ 1 ) AND eat . agent ( x _ 2 , x _ 1 ) AND eat . theme ( x _ 2 , x _ 4 ) AND cake ( x _ 4 )
# Exact match score on first 2003 of COGS dev:
#
# 99.95% or 2002.0 out of 2003 (95% confidence interval: 99.72% to 100.00%)
# Isabella liked that James painted a dog
#  like . agent ( x _ 1 , Isabella ) AND like . ccomp ( x _ 1 , x _ 4 ) AND paint . agent ( x _ 4 , James ) AND paint . theme ( x _ 4 , x _ 6 ) AND dog ( x _ 6 )
# Exact match score on first 2004 of COGS dev:
#
# 99.95% or 2003.0 out of 2004 (95% confidence interval: 99.72% to 100.00%)
# A box was rolled by the dog
#  * dog ( x _ 6 ) ; box ( x _ 1 ) AND roll . theme ( x _ 3 , x _ 1 ) AND roll . agent ( x _ 3 , x _ 6 )
# Exact match score on first 2005 of COGS dev:
#
# 99.95% or 2004.0 out of 2005 (95% confidence interval: 99.72% to 100.00%)
# Emma hoped that the cake was fed to Violet
# ...
